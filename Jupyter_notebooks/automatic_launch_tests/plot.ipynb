# %%
import matplotlib.pyplot as plt
import wntr
import wntr.network.controls as controls
import sqlite3
import csv
import time
import pandas as pd
import statistics

# %%
no_automatic = pd.read_csv('no_automatic/physical_process.csv')
automatic = pd.read_csv('automatic/physical_process.csv')

dd = plt.subplot(2,1,1)
no_automatic["TANK_LEVEL"].plot(label='No automatic', ax=dd)
automatic["TANK_LEVEL"].plot(label='Automatic', ax=dd)
plt.title("MiniCPS simulation - Minitown")
plt.legend()
plt.xlabel('iterations')
plt.ylabel('tank level (m)')
plt.subplots_adjust(top=2.00, right=3.00)
plt.grid(True)
