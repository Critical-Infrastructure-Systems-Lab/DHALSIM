# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %%
#mean_delay = 50.0
mean_delay = 5.0
sigma_delay = math.sqrt( 2*math.pow(mean_delay,2) / math.pi )
sns.distplot(random.rayleigh(scale=sigma_delay, size=10000), hist=False)
plt.show()

# %%
delays = random.rayleigh(scale=sigma_delay, size=100)
plt.hist(delays)
# Out:
# (array([ 5., 14., 17., 13., 15., 17.,  7.,  5.,  6.,  1.]),
#  array([ 0.9852991 ,  3.05392217,  5.12254524,  7.19116832,  9.25979139,
#         11.32841446, 13.39703753, 15.4656606 , 17.53428367, 19.60290674,
#         21.67152981]),
#  <a list of 10 Patch objects>)

# %%
mean_loss = 2
sigma_loss = math.sqrt( 2*math.pow(mean_loss,2) / math.pi )
sns.distplot(random.rayleigh(scale=sigma_loss, size=100), hist=False)
plt.show()

# %%
losses = random.rayleigh(scale=sigma_loss, size=100)
plt.hist(losses)
# Out:
# (array([ 7., 12., 27., 12., 18.,  8.,  8.,  4.,  3.,  1.]),
#  array([0.12207417, 0.59430608, 1.066538  , 1.53876991, 2.01100183,
#         2.48323374, 2.95546565, 3.42769757, 3.89992948, 4.37216139,
#         4.84439331]),
#  <a list of 10 Patch objects>)
