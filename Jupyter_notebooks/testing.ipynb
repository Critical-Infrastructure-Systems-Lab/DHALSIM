# %%
import matplotlib.pyplot as plt
import wntr
import wntr.network.controls as controls
import sqlite3
import csv
import time
import pandas as pd
import statistics

# %%
#no_minicps_data = pd.read_csv('no_minicps_pdd.csv')
#automatic_test = pd.read_csv('experiment_data/testing/output/physical_process.csv')
automatic_test = pd.read_csv('../ICS_topologies/minitown_topology/output/physical_process.csv')

left_lim = 0 
right_lim = 673
subplot_hspace = 0.6
subplot_wspace = 0.1


dd = plt.subplot(3,2,1)
#no_minicps_data["TANK_LEVEL"].plot(label='WNTR', ax=dd)
automatic_test["TANK_LEVEL"].plot(label='Automatic Test', ax=dd)
#week_1["TANK_LEVEL"].plot(label='Week 1', ax=dd)
#week_2["TANK_LEVEL"].plot(label='Week 2', ax=dd)
plt.title("Figure 1. MiniCPS simulation - Pressure Driven. Minitown topology")
plt.legend()
plt.xlabel('iterations')
plt.ylabel('tank level (m)')
plt.xlim(left=left_lim, right=right_lim)
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)

dd = plt.subplot(3,2,2)
#no_minicps_data["STATUS_PUMP1"].plot(label='WNTR', ax=dd)
automatic_test["STATUS_PUMP1"].plot(label='Automatic Test', ax=dd)
#week_1["TANK_LEVEL"].plot(label='Week 1', ax=dd)
#week_2["TANK_LEVEL"].plot(label='Week 2', ax=dd)
plt.title("Figure 1. MiniCPS simulation - Pressure Driven. Minitown topology")
plt.legend()
plt.xlabel('iterations')
plt.ylabel('tank level (m)')
plt.xlim(left=left_lim, right=right_lim)
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)

dd = plt.subplot(3,2,3)
#no_minicps_data["STATUS_PUMP2"].plot(label='WNTR', ax=dd)
automatic_test["STATUS_PUMP2"].plot(label='Automatic Test', ax=dd)
plt.title("Figure 1. MiniCPS simulation - Pressure Driven. Minitown topology")
plt.legend()
plt.xlabel('iterations')
plt.ylabel('tank level (m)')
plt.xlim(left=left_lim, right=right_lim)
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)

dd = plt.subplot(3,2,4)
#no_minicps_data["FLOW_PUMP1"].plot(label='WNTR', ax=dd)
automatic_test["FLOW_PUMP1"].plot(label='Automatic Test', ax=dd)
plt.title("Figure 1. MiniCPS simulation - Pressure Driven. Minitown topology")
plt.legend()
plt.xlabel('iterations')
plt.ylabel('tank level (m)')
plt.xlim(left=left_lim, right=right_lim)
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)

dd = plt.subplot(3,2,5)
#no_minicps_data["FLOW_PUMP2"].plot(label='WNTR', ax=dd)
automatic_test["FLOW_PUMP2"].plot(label='Automatic Test', ax=dd)
plt.title("Figure 1. MiniCPS simulation - Pressure Driven. Minitown topology")
plt.legend()
plt.xlabel('iterations')
plt.ylabel('tank level (m)')
plt.xlim(left=left_lim, right=right_lim)
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)

dd = plt.subplot(3,2,6)
#no_minicps_data["STATUS_PUMP2"].plot(label='WNTR', ax=dd)
automatic_test["STATUS_PUMP2"].plot(label='Automatic Test', ax=dd)
plt.title("Figure 1. MiniCPS simulation - Pressure Driven. Minitown topology")
plt.legend()
plt.xlabel('iterations')
plt.ylabel('tank level (m)')
plt.xlim(left=left_lim, right=right_lim)
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)
