# %%
import matplotlib.pyplot as plt
import wntr
import wntr.network.controls as controls
import sqlite3
import csv
import time
import pandas as pd

# %%
ideal = pd.read_csv('../year_simulation/week_0/physical_process.csv')
no_bw_limit_100_connections = pd.read_csv('../iperf_daily_test/new_tests/no_bw_limit_connections_100/week_0/physical_process.csv')
hundred_bw_limit_100_connections = pd.read_csv('../iperf_daily_test/new_tests/100_bw_limit_connections_100/week_0/physical_process.csv')

# %%
subplot_hspace = 0.6
subplot_wspace = 0.1

dd = plt.subplot(4,2,1)
ideal["T1_LEVEL"].plot(label='No Iperf', ax=dd)
no_bw_limit_100_connections["T1_LEVEL"].plot(label='Iperf - No BW limit - 100 connections', ax=dd)
hundred_bw_limit_100_connections["T1_LEVEL"].plot(label='Iperf - 100 MB BW limit - 100 connections', ax=dd)
plt.title("CTown topology - Tank 1")
plt.xlabel('iterations')
plt.xlim(0,288)
plt.ylabel('tank level (m)')
plt.legend()
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)

dd = plt.subplot(4,2,2)
ideal["T2_LEVEL"].plot(label='No Iperf', ax=dd)
no_bw_limit_100_connections["T2_LEVEL"].plot(label='Iperf - No BW limit - 100 connections', ax=dd)
hundred_bw_limit_100_connections["T2_LEVEL"].plot(label='Iperf - 100 MB BW limit - 100 connections', ax=dd)
plt.title("CTown topology - Tank 2")
plt.xlabel('iterations')
plt.xlim(0,288)
plt.ylabel('tank level (m)')
plt.legend()
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)


dd = plt.subplot(4,2,3)
ideal["T3_LEVEL"].plot(label='No Iperf', ax=dd)
no_bw_limit_100_connections["T3_LEVEL"].plot(label='Iperf - No BW limit - 100 connections', ax=dd)
hundred_bw_limit_100_connections["T3_LEVEL"].plot(label='Iperf - 100 MB BW limit - 100 connections', ax=dd)
plt.title("CTown topology - Tank 3")
plt.xlabel('iterations')
plt.xlim(0,288)
plt.ylabel('tank level (m)')
plt.legend()
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)

dd = plt.subplot(4,2,4)
ideal["T4_LEVEL"].plot(label='No Iperf', ax=dd)
no_bw_limit_100_connections["T4_LEVEL"].plot(label='Iperf - No BW limit - 100 connections', ax=dd)
hundred_bw_limit_100_connections["T4_LEVEL"].plot(label='Iperf - 100 MB BW limit - 100 connections', ax=dd)
plt.title("CTown topology - Tank 4")
plt.xlabel('iterations')
plt.xlim(0,288)
plt.ylabel('tank level (m)')
plt.legend()
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)


dd = plt.subplot(4,2,5)
ideal["T5_LEVEL"].plot(label='No Iperf', ax=dd)
no_bw_limit_100_connections["T5_LEVEL"].plot(label='Iperf - No BW limit - 100 connections', ax=dd)
hundred_bw_limit_100_connections["T5_LEVEL"].plot(label='Iperf - 100 MB BW limit - 100 connections', ax=dd)
plt.title("CTown topology - Tank 5")
plt.xlabel('iterations')
plt.xlim(0,288)
plt.ylabel('tank level (m)')
plt.legend()
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)

dd = plt.subplot(4,2,6)
ideal["T6_LEVEL"].plot(label='No Iperf', ax=dd)
no_bw_limit_100_connections["T6_LEVEL"].plot(label='Iperf - No BW limit - 100 connections', ax=dd)
hundred_bw_limit_100_connections["T6_LEVEL"].plot(label='Iperf - 100 MB BW limit - 100 connections', ax=dd)
plt.title("CTown topology - Tank 6")
plt.xlabel('iterations')
plt.xlim(0,288)
plt.ylabel('tank level (m)')
plt.legend()
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)

dd = plt.subplot(4,2,7)
ideal["T7_LEVEL"].plot(label='No Iperf', ax=dd)
no_bw_limit_100_connections["T7_LEVEL"].plot(label='Iperf - No BW limit - 100 connections', ax=dd)
hundred_bw_limit_100_connections["T7_LEVEL"].plot(label='Iperf - 100 MB BW limit - 100 connections', ax=dd)
plt.title("CTown topology - Tank 7")
plt.xlabel('iterations')
plt.xlim(0,288)
plt.ylabel('tank level (m)')
plt.legend()
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)
