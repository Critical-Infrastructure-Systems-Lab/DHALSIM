# %%
import matplotlib.pyplot as plt
import wntr
import wntr.network.controls as controls
import sqlite3
import csv
import time
import pandas as pd

# %%
laptop_no_iperf = pd.read_csv('../year_simulation/week_0/physical_process.csv')
laptop_iperf_100_connections_noiperfbw_link_bw_10 = pd.read_csv('new_tests_laptop/laptop_iperf_100_connections_noiperfbw_link_bw_10/week_0/physical_process.csv')
laptop_iperf_1_connections_noiperfbw_link_bw_10 = pd.read_csv('new_tests_laptop/laptop_iperf_1_connections_noiperfbw_link_bw_10/week_0/physical_process.csv')
laptop_iperf_1_connections_noiperfbw_link_bw_1000 = pd.read_csv('new_tests_laptop/laptop_iperf_1_connections_noiperfbw_link_bw_1000/week_0/physical_process.csv')
laptop_iperf_100_connections_noiperfbw_link_bw_1000 = pd.read_csv('new_tests_laptop/laptop_iperf_100_connections_noiperfbw_link_bw_1000/week_0/physical_process.csv')
subplot_hspace = 0.6
subplot_wspace = 0.1

dd = plt.subplot(4,2,1)
laptop_no_iperf["T1_LEVEL"].plot(label='No Iperf', ax=dd)
laptop_iperf_100_connections_noiperfbw_link_bw_10["T1_LEVEL"].plot(label='-P 100. -B 10', ax=dd)
laptop_iperf_1_connections_noiperfbw_link_bw_10["T1_LEVEL"].plot(label='-P 1. -B 10', ax=dd)
laptop_iperf_1_connections_noiperfbw_link_bw_1000["T1_LEVEL"].plot(label='-P 1. -B 1000', ax=dd)
laptop_iperf_100_connections_noiperfbw_link_bw_1000["T1_LEVEL"].plot(label='-P 100. -B 1000', ax=dd)
plt.title("CTown topology - Tank 1")
plt.xlabel('iterations')
plt.xlim(0,288)
plt.ylabel('tank level (m)')
plt.legend()
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)

dd = plt.subplot(4,2,2)
laptop_no_iperf["T2_LEVEL"].plot(label='Laptop - No Iperf', ax=dd)
laptop_iperf_100_connections_noiperfbw_link_bw_10["T2_LEVEL"].plot(label='-P 100. -B 10', ax=dd)
laptop_iperf_1_connections_noiperfbw_link_bw_10["T2_LEVEL"].plot(label='-P 1. -B 10', ax=dd)
laptop_iperf_1_connections_noiperfbw_link_bw_1000["T2_LEVEL"].plot(label='-P 1. -B 1000', ax=dd)
laptop_iperf_100_connections_noiperfbw_link_bw_1000["T2_LEVEL"].plot(label='-P 100. -B 1000', ax=dd)
plt.title("CTown topology - Tank 2")
plt.xlabel('iterations')
plt.xlim(0,288)
plt.ylabel('tank level (m)')
plt.legend()
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)

dd = plt.subplot(4,2,3)
laptop_no_iperf["T3_LEVEL"].plot(label='Laptop - No Iperf', ax=dd)
laptop_iperf_100_connections_noiperfbw_link_bw_10["T3_LEVEL"].plot(label='-P 100. -B 10', ax=dd)
laptop_iperf_1_connections_noiperfbw_link_bw_10["T3_LEVEL"].plot(label='-P 1. -B 10', ax=dd)
laptop_iperf_1_connections_noiperfbw_link_bw_1000["T3_LEVEL"].plot(label='-P 1. -B 1000', ax=dd)
laptop_iperf_100_connections_noiperfbw_link_bw_1000["T3_LEVEL"].plot(label='-P 100. -B 1000', ax=dd)
plt.title("CTown topology - Tank 3")
plt.xlabel('iterations')
plt.xlim(0,288)
plt.ylabel('tank level (m)')
plt.legend()
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)

dd = plt.subplot(4,2,4)
laptop_no_iperf["T4_LEVEL"].plot(label='Laptop - No Iperf', ax=dd)
laptop_iperf_100_connections_noiperfbw_link_bw_10["T4_LEVEL"].plot(label='-P 100. -B 10', ax=dd)
laptop_iperf_1_connections_noiperfbw_link_bw_10["T4_LEVEL"].plot(label='-P 1. -B 10', ax=dd)
laptop_iperf_1_connections_noiperfbw_link_bw_1000["T4_LEVEL"].plot(label='-P 1. -B 1000', ax=dd)
laptop_iperf_100_connections_noiperfbw_link_bw_1000["T4_LEVEL"].plot(label='-P 100. -B 1000', ax=dd)
plt.title("CTown topology - Tank 4")
plt.xlabel('iterations')
plt.xlim(0,288)
plt.ylabel('tank level (m)')
plt.legend()
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)

dd = plt.subplot(4,2,5)
laptop_no_iperf["T5_LEVEL"].plot(label='Laptop - No Iperf', ax=dd)
laptop_iperf_100_connections_noiperfbw_link_bw_10["T5_LEVEL"].plot(label='-P 100. -B 10', ax=dd)
laptop_iperf_1_connections_noiperfbw_link_bw_10["T5_LEVEL"].plot(label='-P 1. -B 10', ax=dd)
laptop_iperf_1_connections_noiperfbw_link_bw_1000["T5_LEVEL"].plot(label='-P 1. -B 1000', ax=dd)
laptop_iperf_100_connections_noiperfbw_link_bw_1000["T5_LEVEL"].plot(label='-P 100. -B 1000', ax=dd)
plt.title("CTown topology - Tank 5")
plt.xlabel('iterations')
plt.xlim(0,288)
plt.ylabel('tank level (m)')
plt.legend()
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)

dd = plt.subplot(4,2,6)
laptop_no_iperf["T6_LEVEL"].plot(label='Laptop - No Iperf', ax=dd)
laptop_iperf_100_connections_noiperfbw_link_bw_10["T6_LEVEL"].plot(label='-P 100. -B 10', ax=dd)
laptop_iperf_1_connections_noiperfbw_link_bw_10["T6_LEVEL"].plot(label='-P 1. -B 10', ax=dd)
laptop_iperf_1_connections_noiperfbw_link_bw_1000["T6_LEVEL"].plot(label='-P 1. -B 1000', ax=dd)
laptop_iperf_100_connections_noiperfbw_link_bw_1000["T6_LEVEL"].plot(label='-P 100. -B 1000', ax=dd)
plt.title("CTown topology - Tank 6")
plt.xlabel('iterations')
plt.xlim(0,288)
plt.ylabel('tank level (m)')
plt.legend()
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)

dd = plt.subplot(4,2,7)
laptop_no_iperf["T7_LEVEL"].plot(label='Laptop - No Iperf', ax=dd)
laptop_iperf_100_connections_noiperfbw_link_bw_10["T7_LEVEL"].plot(label='-P 100. -B 10', ax=dd)
laptop_iperf_1_connections_noiperfbw_link_bw_10["T7_LEVEL"].plot(label='-P 1. -B 10', ax=dd)
laptop_iperf_1_connections_noiperfbw_link_bw_1000["T7_LEVEL"].plot(label='-P 1. -B 1000', ax=dd)
laptop_iperf_100_connections_noiperfbw_link_bw_1000["T7_LEVEL"].plot(label='-P 100. -B 1000', ax=dd)
plt.title("CTown topology topology - Tank 7")
plt.xlabel('iterations')
plt.xlim(0,288)
plt.ylabel('tank level (m)')
plt.legend()
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)
