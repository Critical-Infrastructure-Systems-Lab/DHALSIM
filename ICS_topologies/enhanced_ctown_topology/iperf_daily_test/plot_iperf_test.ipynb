# %%
import matplotlib.pyplot as plt
import wntr
import wntr.network.controls as controls
import sqlite3
import csv
import time
import pandas as pd

# %%
laptop_no_iperf = pd.read_csv('../year_simulation/one_day_laptop_test/week_0/physical_process.csv')
desktop_no_iperf = pd.read_csv('../year_simulation/one_day_desktop_test/week_0/physical_process.csv')
#ideal = pd.read_csv('../year_simulation/week_0/physical_process.csv')
ideal = pd.read_csv('../year_simulation/desktop_week_0_new_test/week_0/physical_process.csv')
one_connection = pd.read_csv('01_concurrent_connections/week_0/physical_process.csv')

desktop_one_connection_1mb_long = pd.read_csv('bw_1m_01_concurrent_long_iperf/week_0/physical_process.csv')

#ten_connection = pd.read_csv('10_concurrent_connections/week_0/physical_process.csv')
#hundred_connection = pd.read_csv('100_concurrent_connections/week_0/physical_process.csv')
#basic_ctown = pd.read_csv('week_11/physical_process.csv')
#basic_ctown_2 = pd.read_csv('week_12/physical_process.csv')
subplot_hspace = 0.6
subplot_wspace = 0.1

dd = plt.subplot(4,2,1)
ideal["T1_LEVEL"].plot(label='No Iperf', ax=dd)
laptop_no_iperf["T1_LEVEL"].plot(label='Laptop - No Iperf', ax=dd)
desktop_no_iperf["T1_LEVEL"].plot(label='Desktop - No Iperf', ax=dd)
desktop_one_connection_1mb_long["T1_LEVEL"].plot(label='Desktop - Iperf - 1c. 1MB - 2400 secs', ax=dd)

#one_connection["T1_LEVEL"].plot(label='One concurrent connection', ax=dd)
#ten_connection["T1_LEVEL"].plot(label='Ten concurrent connections', ax=dd)
#hundred_connection["T1_LEVEL"].plot(label='Hundred concurrent connections', ax=dd)
plt.title("CTown topology - Tank 1")
plt.xlabel('iterations')
plt.xlim(0,288)
plt.ylabel('tank level (m)')
plt.legend()
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)

dd = plt.subplot(4,2,2)
#ideal["T2_LEVEL"].plot(label='No Iperf', ax=dd)
laptop_no_iperf["T2_LEVEL"].plot(label='Laptop - No Iperf', ax=dd)
desktop_no_iperf["T2_LEVEL"].plot(label='Desktop - No Iperf', ax=dd)
desktop_one_connection_1mb_long["T2_LEVEL"].plot(label='Desktop - Iperf - 1c. 1MB - 2400 secs', ax=dd)
#one_connection["T2_LEVEL"].plot(label='One concurrent connection', ax=dd)
#ten_connection["T2_LEVEL"].plot(label='Ten concurrent connections', ax=dd)
#hundred_connection["T2_LEVEL"].plot(label='Hundred concurrent connections', ax=dd)
plt.title("CTown topology - Tank 2")
plt.xlabel('iterations')
plt.xlim(0,288)
plt.ylabel('tank level (m)')
plt.legend()
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)

dd = plt.subplot(4,2,3)
#ideal["T3_LEVEL"].plot(label='No Iperf', ax=dd)
laptop_no_iperf["T3_LEVEL"].plot(label='Laptop - No Iperf', ax=dd)
desktop_no_iperf["T3_LEVEL"].plot(label='Desktop - No Iperf', ax=dd)
desktop_one_connection_1mb_long["T3_LEVEL"].plot(label='Desktop - Iperf - 1c. 1MB - 2400 secs', ax=dd)
#one_connection["T3_LEVEL"].plot(label='One concurrent connection', ax=dd)
#ten_connection["T3_LEVEL"].plot(label='Ten concurrent connections', ax=dd)
#hundred_connection["T3_LEVEL"].plot(label='Hundred concurrent connections', ax=dd)
plt.title("CTown topology - Tank 3")
plt.xlabel('iterations')
plt.xlim(0,288)
plt.ylabel('tank level (m)')
plt.legend()
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)

dd = plt.subplot(4,2,4)
#ideal["T4_LEVEL"].plot(label='No Iperf', ax=dd)
laptop_no_iperf["T4_LEVEL"].plot(label='Laptop - No Iperf', ax=dd)
desktop_no_iperf["T4_LEVEL"].plot(label='Desktop - No Iperf', ax=dd)
desktop_one_connection_1mb_long["T4_LEVEL"].plot(label='Desktop - Iperf - 1c. 1MB - 2400 secs', ax=dd)
#one_connection["T4_LEVEL"].plot(label='One concurrent connection', ax=dd)
#ten_connection["T4_LEVEL"].plot(label='Ten concurrent connections', ax=dd)
#hundred_connection["T4_LEVEL"].plot(label='Hundred concurrent connections', ax=dd)
plt.title("CTown topology - Tank 4")
plt.xlabel('iterations')
plt.xlim(0,288)
plt.ylabel('tank level (m)')
plt.legend()
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)

dd = plt.subplot(4,2,5)
#ideal["T5_LEVEL"].plot(label='No Iperf', ax=dd)
laptop_no_iperf["T5_LEVEL"].plot(label='Laptop - No Iperf', ax=dd)
desktop_no_iperf["T5_LEVEL"].plot(label='Desktop - No Iperf', ax=dd)
desktop_one_connection_1mb_long["T5_LEVEL"].plot(label='Desktop - Iperf - 1c. 1MB - 2400 secs', ax=dd)
#one_connection["T5_LEVEL"].plot(label='One concurrent connection', ax=dd)
#ten_connection["T5_LEVEL"].plot(label='Ten concurrent connections', ax=dd)
#hundred_connection["T5_LEVEL"].plot(label='Hundred concurrent connections', ax=dd)
plt.title("CTown topology - Tank 5")
plt.xlabel('iterations')
plt.xlim(0,288)
plt.ylabel('tank level (m)')
plt.legend()
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)

dd = plt.subplot(4,2,6)
#ideal["T6_LEVEL"].plot(label='No Iperf', ax=dd)
laptop_no_iperf["T6_LEVEL"].plot(label='Laptop - No Iperf', ax=dd)
desktop_no_iperf["T6_LEVEL"].plot(label='Desktop - No Iperf', ax=dd)
desktop_one_connection_1mb_long["T6_LEVEL"].plot(label='Desktop - Iperf - 1c. 1MB - 2400 secs', ax=dd)
#one_connection["T6_LEVEL"].plot(label='One concurrent connection', ax=dd)
#ten_connection["T6_LEVEL"].plot(label='Ten concurrent connections', ax=dd)
#hundred_connection["T6_LEVEL"].plot(label='Hundred concurrent connections', ax=dd)
plt.title("CTown topology - Tank 6")
plt.xlabel('iterations')
plt.xlim(0,288)
plt.ylabel('tank level (m)')
plt.legend()
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)

dd = plt.subplot(4,2,7)
#ideal["T7_LEVEL"].plot(label='No Iperf', ax=dd)
laptop_no_iperf["T7_LEVEL"].plot(label='Laptop - No Iperf', ax=dd)
desktop_no_iperf["T7_LEVEL"].plot(label='Desktop - No Iperf', ax=dd)
desktop_one_connection_1mb_long["T7_LEVEL"].plot(label='Desktop - Iperf - 1c. 1MB - 2400 secs', ax=dd)
#one_connection["T7_LEVEL"].plot(label='One concurrent connection', ax=dd)
#ten_connection["T7_LEVEL"].plot(label='Ten concurrent connections', ax=dd)
#hundred_connection["T7_LEVEL"].plot(label='Hundred concurrent connections', ax=dd)
plt.title("CTown topology topology - Tank 7")
plt.xlabel('iterations')
plt.xlim(0,288)
plt.ylabel('tank level (m)')
plt.legend()
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)

# %%
ideal = pd.read_csv('../year_simulation/week_0/physical_process.csv')
#one_mb_one_connection = pd.read_csv('bw_limit_1m_01_concurrent/week_0/physical_process.csv')
#one_connection = pd.read_csv('01_concurrent_connections/week_0/physical_process.csv')
#ten_connection = pd.read_csv('10_concurrent_connections/week_0/physical_process.csv')
#hundred_connection = pd.read_csv('100_concurrent_connections/week_0/physical_process.csv')
subplot_hspace = 0.6
subplot_wspace = 0.1

dd = plt.subplot(4,2,1)
ideal["T1_LEVEL"].plot(label='No Iperf', ax=dd)
one_mb_one_connection["T1_LEVEL"].plot(label='1MB - 1 Connection ', ax=dd)
one_connection["T1_LEVEL"].plot(label='No limit - 1 Connection ', ax=dd)
#ten_connection["T1_LEVEL"].plot(label='Ten concurrent connections', ax=dd)
#hundred_connection["T1_LEVEL"].plot(label='Hundred concurrent connections', ax=dd)
plt.title("CTown topology - Tank 1")
plt.xlabel('iterations')
plt.xlim(0,288)
plt.ylabel('tank level (m)')
plt.legend()
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)

dd = plt.subplot(4,2,2)
ideal["T2_LEVEL"].plot(label='No Iperf', ax=dd)
one_mb_one_connection["T2_LEVEL"].plot(label='1MB - 1 Connection ', ax=dd)
one_connection["T2_LEVEL"].plot(label='No limit - 1 Connection ', ax=dd)
#ten_connection["T2_LEVEL"].plot(label='Ten concurrent connections', ax=dd)
#hundred_connection["T2_LEVEL"].plot(label='Hundred concurrent connections', ax=dd)
plt.title("CTown topology - Tank 2")
plt.xlabel('iterations')
plt.xlim(0,288)
plt.ylabel('tank level (m)')
plt.legend()
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)

dd = plt.subplot(4,2,3)
ideal["T3_LEVEL"].plot(label='No Iperf', ax=dd)
one_mb_one_connection["T3_LEVEL"].plot(label='1MB - 1 Connection ', ax=dd)
one_connection["T3_LEVEL"].plot(label='No limit - 1 Connection ', ax=dd)
#ten_connection["T3_LEVEL"].plot(label='Ten concurrent connections', ax=dd)
#hundred_connection["T3_LEVEL"].plot(label='Hundred concurrent connections', ax=dd)
plt.title("CTown topology - Tank 3")
plt.xlabel('iterations')
plt.xlim(0,288)
plt.ylabel('tank level (m)')
plt.legend()
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)

dd = plt.subplot(4,2,4)
ideal["T4_LEVEL"].plot(label='No Iperf', ax=dd)
one_mb_one_connection["T4_LEVEL"].plot(label='1MB - 1 Connection ', ax=dd)
one_connection["T4_LEVEL"].plot(label='No limit - 1 Connection ', ax=dd)
#ten_connection["T4_LEVEL"].plot(label='Ten concurrent connections', ax=dd)
#hundred_connection["T4_LEVEL"].plot(label='Hundred concurrent connections', ax=dd)
plt.title("CTown topology - Tank 4")
plt.xlabel('iterations')
plt.xlim(0,288)
plt.ylabel('tank level (m)')
plt.legend()
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)

dd = plt.subplot(4,2,5)
ideal["T5_LEVEL"].plot(label='No Iperf', ax=dd)
one_mb_one_connection["T5_LEVEL"].plot(label='1MB - 1 Connection ', ax=dd)
one_connection["T5_LEVEL"].plot(label='No limit - 1 Connection ', ax=dd)
plt.title("CTown topology - Tank 5")
plt.xlabel('iterations')
plt.xlim(0,288)
plt.ylabel('tank level (m)')
plt.legend()
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)

dd = plt.subplot(4,2,6)
ideal["T6_LEVEL"].plot(label='No Iperf', ax=dd)
one_mb_one_connection["T6_LEVEL"].plot(label='1MB - 1 Connection ', ax=dd)
one_connection["T6_LEVEL"].plot(label='No limit - 1 Connection ', ax=dd)
plt.title("CTown topology - Tank 6")
plt.xlabel('iterations')
plt.xlim(0,288)
plt.ylabel('tank level (m)')
plt.legend()
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)

dd = plt.subplot(4,2,7)
ideal["T7_LEVEL"].plot(label='No Iperf', ax=dd)
one_mb_one_connection["T7_LEVEL"].plot(label='1MB - 1 Connection ', ax=dd)
one_connection["T7_LEVEL"].plot(label='No limit - 1 Connection ', ax=dd)
plt.title("CTown topology topology - Tank 7")
plt.xlabel('iterations')
plt.xlim(0,288)
plt.ylabel('tank level (m)')
plt.legend()
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)
