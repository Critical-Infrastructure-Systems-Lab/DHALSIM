# %% [markdown]
# # Enhanced C-Town Topology plots
#
# The enhanced C-Town topology tries to create a more complex and realistic network topology for a water distribution system like C-Town. In this topology, we assume that is not feasible possible for all PLCs to be in the same substation and hence are also not in the same Local Area Network (LAN). In this sense, each PLC is in a different LAN. The PLC3 shares the LAN with the SCADA server. In addition, the PLCs and SCADA using private IP addressing and NAT and port forwarding is used in the routers to enable communication between them. We argue this is a fairly realistic scenario

# %%
import matplotlib.pyplot as plt
import wntr
import wntr.network.controls as controls
import sqlite3
import csv
import time
import pandas as pd

# %%
no_minicps_ctown = pd.read_csv('no_attack/output/physical_process.csv')
minicps_ctown = pd.read_csv('new_icss_paper_attacks/normal_behaviour/week_0/physical_process.csv')
minicps_ctown_physical = pd.read_csv('api_tests/scada_test/week_0/physical_process.csv')
#minicps_ctown_plc1_attack = pd.read_csv('plc1_attack/output/physical_process.csv')
#minicps_ctown_mitm_plc5_attack = pd.read_csv('mitm_plc5_attack/output/physical_process.csv')
#minicps_ctown_plc1_exp_attack = pd.read_csv('vm_tests/tank_1_empty_exponential/week_19/physical_process.csv')
#minicps_ctown_plc7_plc5_exp_attack = pd.read_csv('icss_paper_attacks/tank_5_overflow_exponential_1_day/week_19/physical_process.csv')

subplot_hspace = 0.6
subplot_wspace = 0.1

dd = plt.subplot(4,2,1)
minicps_ctown["T1_LEVEL"].plot(label='MiniCPS - PDD', ax=dd)
minicps_ctown_physical["T1_LEVEL"].plot(label='Physical Process Test', ax=dd)
#lt.xlim(left=0, right=2)
#minicps_ctown_plc1_attack["T1_LEVEL"].plot(label='MiniCPS - PLC1 Attack', ax=dd)
#minicps_ctown_mitm_plc5_attack["T1_LEVEL"].plot(label='MiniCPS - Mitm PLC5 Attack', ax=dd)
#minicps_ctown_plc7_plc5_exp_attack["T1_LEVEL"].plot(label='C-Town PLC7 Exponential Attack', ax=dd)
plt.title("CTown topology - Tank 1")
plt.xlabel('iterations')
plt.ylabel('tank level (m)')
plt.legend()
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)

dd = plt.subplot(4,2,2)
minicps_ctown["T2_LEVEL"].plot(label='MiniCPS - PDD', ax=dd)
minicps_ctown_physical["T2_LEVEL"].plot(label='Physical Process Test', ax=dd)
plt.xlim(left=0, right=288)
#minicps_ctown_plc1_attack["T2_LEVEL"].plot(label='MiniCPS - PLC1 Attack', ax=dd)
#minicps_ctown_mitm_plc5_attack["T2_LEVEL"].plot(label='MiniCPS - Mitm PLC5 Attack', ax=dd)
#minicps_ctown_plc7_plc5_exp_attack["T2_LEVEL"].plot(label='C-Town PLC7 Exponential Attack', ax=dd)
plt.title("CTown topology - Tank 2")
plt.xlabel('iterations')
plt.ylabel('tank level (m)')
plt.legend()
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)

dd = plt.subplot(4,2,3)
minicps_ctown["T3_LEVEL"].plot(label='MiniCPS - PDD', ax=dd)
minicps_ctown_physical["T3_LEVEL"].plot(label='Physical Process Test', ax=dd)
plt.xlim(left=0, right=288)
#minicps_ctown_plc1_attack["T3_LEVEL"].plot(label='MiniCPS - PLC1 Attack', ax=dd)
#minicps_ctown_mitm_plc5_attack["T3_LEVEL"].plot(label='MiniCPS - Mitm PLC5 Attack', ax=dd)
#minicps_ctown_plc7_plc5_exp_attack["T3_LEVEL"].plot(label='C-Town PLC7 Exponential Attack', ax=dd)
plt.title("CTown topology - Tank 3")
plt.xlabel('iterations')
plt.ylabel('tank level (m)')
plt.legend()
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)

dd = plt.subplot(4,2,4)
minicps_ctown["T4_LEVEL"].plot(label='MiniCPS - PDD', ax=dd)
minicps_ctown_physical["T4_LEVEL"].plot(label='Physical Process Test', ax=dd)
plt.xlim(left=0, right=288)
#minicps_ctown_plc1_attack["T4_LEVEL"].plot(label='MiniCPS - PLC1 Attack', ax=dd)
#minicps_ctown_mitm_plc5_attack["T4_LEVEL"].plot(label='MiniCPS - Mitm PLC5 Attack', ax=dd)
#minicps_ctown_plc7_plc5_exp_attack["T4_LEVEL"].plot(label='C-Town PLC7 Exponential Attack', ax=dd)
plt.title("CTown topology - Tank 4")
plt.xlabel('iterations')
plt.ylabel('tank level (m)')
plt.legend()
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)

dd = plt.subplot(4,2,5)
minicps_ctown["T5_LEVEL"].plot(label='MiniCPS - PDD', ax=dd)
minicps_ctown_physical["T5_LEVEL"].plot(label='Physical Process Test', ax=dd)
plt.xlim(left=0, right=288)
#minicps_ctown_plc1_attack["T5_LEVEL"].plot(label='MiniCPS - PLC1 Attack', ax=dd)
#minicps_ctown_mitm_plc5_attack["T5_LEVEL"].plot(label='MiniCPS - Mitm PLC5 Attack', ax=dd)
#minicps_ctown_plc7_plc5_exp_attack["T5_LEVEL"].plot(label='C-Town PLC7 Exponential Attack', ax=dd)
plt.title("CTown topology - Tank 5")
plt.xlabel('iterations')
plt.ylabel('tank level (m)')
plt.legend()
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)

dd = plt.subplot(4,2,6)
minicps_ctown["T6_LEVEL"].plot(label='MiniCPS - PDD', ax=dd)
minicps_ctown_physical["T6_LEVEL"].plot(label='Physical Process Test', ax=dd)
plt.xlim(left=0, right=288)
#minicps_ctown_plc1_attack["T6_LEVEL"].plot(label='MiniCPS - PLC1 Attack', ax=dd)
#minicps_ctown_mitm_plc5_attack["T6_LEVEL"].plot(label='MiniCPS - Mitm PLC5 Attack', ax=dd)
#minicps_ctown_plc7_plc5_exp_attack["T6_LEVEL"].plot(label='C-Town PLC7 Exponential Attack', ax=dd)
plt.title("CTown topology - Tank 6")
plt.xlabel('iterations')
plt.ylabel('tank level (m)')
plt.legend()
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)

dd = plt.subplot(4,2,7)
minicps_ctown["T7_LEVEL"].plot(label='MiniCPS - PDD', ax=dd)
minicps_ctown_physical["T7_LEVEL"].plot(label='Physical Process Test', ax=dd)
plt.xlim(left=0, right=288)
#minicps_ctown_plc1_attack["T7_LEVEL"].plot(label='MiniCPS - PLC1 Attack', ax=dd)
#minicps_ctown_mitm_plc5_attack["T7_LEVEL"].plot(label='MiniCPS - Mitm PLC5 Attack', ax=dd)
#minicps_ctown_plc7_plc5_exp_attack["T7_LEVEL"].plot(label='C-Town PLC7 Exponential Attack', ax=dd)
plt.title("CTown topology topology - Tank 7")
plt.xlabel('iterations')
plt.ylabel('tank level (m)')
plt.legend()
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)
