# %% [markdown]
# # Enhanced C-Town Topology plots
#
# The enhanced C-Town topology tries to create a more complex and realistic network topology for a water distribution system like C-Town. In this topology, we assume that is not feasible possible for all PLCs to be in the same substation and hence are also not in the same Local Area Network (LAN). In this sense, each PLC is in a different LAN. The PLC3 shares the LAN with the SCADA server. In addition, the PLCs and SCADA using private IP addressing and NAT and port forwarding is used in the routers to enable communication between them. We argue this is a fairly realistic scenario

# %%
import matplotlib.pyplot as plt
import wntr
import wntr.network.controls as controls
import sqlite3
import csv
import time
import pandas as pd

# %%
minicps_ctown = pd.read_csv('icss_paper_attacks/normal_behavior/week_0/physical_process.csv')
#minicps_ctown = pd.read_csv('new_icss_paper_attacks/normal_behaviour/week_0/physical_process.csv')
#minicps_ctown_synched = pd.read_csv('api_debug/normal_behaviour_synched/week_0/physical_process.csv')
minicps_ctown_synched = pd.read_csv('api_debug/generic_plc1_test/week_0/physical_process.csv')
minicps_ctown_general_plc = pd.read_csv('api_debug/generic_plc_test/week_0/physical_process.csv')
minicps_ctown_general_run = pd.read_csv('api_debug/generic_run/week_0/physical_process.csv')
minicps_ctown_new_year = pd.read_csv('epanet_wntr_comparison/week_0/physical_process.csv')

#minicps_ctown_plc1_attack_no_change = pd.read_csv('api_debug/synched_tank_1_empty_1_pu1_pu2_no_change/week_0/physical_process.csv')
#minicps_ctown_plc1_attack_off = pd.read_csv('api_debug/synched_tank_1_empty_1_pu1_pu2_off/week_0/physical_process.csv')
#minicps_ctown_mitm_plc5_attack = pd.read_csv('mitm_plc5_attack/output/physical_process.csv')
#minicps_ctown_plc1_exp_attack = pd.read_csv('vm_tests/tank_1_empty_exponential/week_19/physical_process.csv')
#minicps_ctown_plc7_plc5_exp_attack = pd.read_csv('icss_paper_attacks/tank_5_overflow_exponential_1_day/week_19/physical_process.csv')

subplot_hspace = 0.6
subplot_wspace = 0.1

dd = plt.subplot(4,2,1)
minicps_ctown["T1_LEVEL"].plot(label='MiniCPS - PDD', ax=dd)
#minicps_ctown_synched["T1_LEVEL"].plot(label='Generic PLC1 Test', ax=dd)
minicps_ctown_general_plc["T1_LEVEL"].plot(label='Generic Test', ax=dd)
minicps_ctown_general_run["T1_LEVEL"].plot(label='Generic Run', ax=dd)
minicps_ctown_new_year["T1_LEVEL"].plot(label='New Year Run', ax=dd)
#lt.xlim(left=0, right=2)
#minicps_ctown_plc1_attack_no_change["T1_LEVEL"].plot(label='Synch - PLC1 Attack - No change', ax=dd)
#minicps_ctown_plc1_attack_off["T1_LEVEL"].plot(label='Synch - PLC1 Attack', ax=dd)
#minicps_ctown_mitm_plc5_attack["T1_LEVEL"].plot(label='MiniCPS - Mitm PLC5 Attack', ax=dd)
#minicps_ctown_plc7_plc5_exp_attack["T1_LEVEL"].plot(label='C-Town PLC7 Exponential Attack', ax=dd)
plt.title("CTown topology - Tank 1")
plt.xlabel('iterations')
plt.ylabel('tank level (m)')
plt.xlim(left=0, right=288)
plt.legend()
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)

dd = plt.subplot(4,2,2)
minicps_ctown["T2_LEVEL"].plot(label='MiniCPS - PDD', ax=dd)
#minicps_ctown_synched["T2_LEVEL"].plot(label='Generic PLC1 Test', ax=dd)
minicps_ctown_general_plc["T2_LEVEL"].plot(label='Generic Test', ax=dd)
minicps_ctown_general_run["T2_LEVEL"].plot(label='Generic Run', ax=dd)
minicps_ctown_new_year["T2_LEVEL"].plot(label='New Year Run', ax=dd)
#minicps_ctown_plc1_attack_no_change["T2_LEVEL"].plot(label='Synch - PLC1 Attack - No change', ax=dd)
#minicps_ctown_plc1_attack_off["T2_LEVEL"].plot(label='Synch - PLC1 Attack', ax=dd)
#minicps_ctown_mitm_plc5_attack["T2_LEVEL"].plot(label='MiniCPS - Mitm PLC5 Attack', ax=dd)
#minicps_ctown_plc7_plc5_exp_attack["T2_LEVEL"].plot(label='C-Town PLC7 Exponential Attack', ax=dd)
plt.title("CTown topology - Tank 2")
plt.xlabel('iterations')
plt.ylabel('tank level (m)')
plt.xlim(left=0, right=288)
plt.legend()
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)

dd = plt.subplot(4,2,3)
minicps_ctown["T3_LEVEL"].plot(label='MiniCPS - PDD', ax=dd)
minicps_ctown_synched["T3_LEVEL"].plot(label='Generic PLC1 Test', ax=dd)
minicps_ctown_general_plc["T3_LEVEL"].plot(label='Generic Test', ax=dd)
minicps_ctown_new_year["T3_LEVEL"].plot(label='New Year Run', ax=dd)
#minicps_ctown_plc1_attack_no_change["T3_LEVEL"].plot(label='Synch - PLC1 Attack - No change', ax=dd)
#minicps_ctown_plc1_attack_off["T3_LEVEL"].plot(label='Synch - PLC1 Attack', ax=dd)
#minicps_ctown_mitm_plc5_attack["T3_LEVEL"].plot(label='MiniCPS - Mitm PLC5 Attack', ax=dd)
#minicps_ctown_plc7_plc5_exp_attack["T3_LEVEL"].plot(label='C-Town PLC7 Exponential Attack', ax=dd)
plt.title("CTown topology - Tank 3")
plt.xlabel('iterations')
plt.ylabel('tank level (m)')
plt.xlim(left=0, right=288)
plt.legend()
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)

dd = plt.subplot(4,2,4)
minicps_ctown["T4_LEVEL"].plot(label='MiniCPS - PDD', ax=dd)
#minicps_ctown_synched["T4_LEVEL"].plot(label='Generic PLC1 Test', ax=dd)
minicps_ctown_general_plc["T4_LEVEL"].plot(label='Generic Test', ax=dd)
minicps_ctown_general_run["T4_LEVEL"].plot(label='Generic Run', ax=dd)
minicps_ctown_new_year["T4_LEVEL"].plot(label='New Year Run', ax=dd)
#minicps_ctown_plc1_attack_no_change["T4_LEVEL"].plot(label='Synch - PLC1 Attack - No change', ax=dd)
#minicps_ctown_plc1_attack_off["T4_LEVEL"].plot(label='Synch - PLC1 Attack', ax=dd)
#minicps_ctown_mitm_plc5_attack["T4_LEVEL"].plot(label='MiniCPS - Mitm PLC5 Attack', ax=dd)
#minicps_ctown_plc7_plc5_exp_attack["T4_LEVEL"].plot(label='C-Town PLC7 Exponential Attack', ax=dd)
plt.title("CTown topology - Tank 4")
plt.xlabel('iterations')
plt.ylabel('tank level (m)')
plt.xlim(left=0, right=288)
plt.legend()
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)

dd = plt.subplot(4,2,5)
minicps_ctown["T5_LEVEL"].plot(label='MiniCPS - PDD', ax=dd)
#minicps_ctown_synched["T5_LEVEL"].plot(label='Generic PLC1 Test', ax=dd)
minicps_ctown_general_plc["T5_LEVEL"].plot(label='Generic Test', ax=dd)
minicps_ctown_general_run["T5_LEVEL"].plot(label='Generic Run', ax=dd)
minicps_ctown_new_year["T5_LEVEL"].plot(label='New Year Run', ax=dd)
plt.xlim(left=0, right=288)
#minicps_ctown_plc1_attack_no_change["T5_LEVEL"].plot(label='MiniCPS - PLC1 Attack - No change', ax=dd)
#minicps_ctown_plc1_attack_off["T5_LEVEL"].plot(label='Synch - PLC1 Attack', ax=dd)
#minicps_ctown_mitm_plc5_attack["T5_LEVEL"].plot(label='MiniCPS - Mitm PLC5 Attack', ax=dd)
#minicps_ctown_plc7_plc5_exp_attack["T5_LEVEL"].plot(label='C-Town PLC7 Exponential Attack', ax=dd)
plt.title("CTown topology - Tank 5")
plt.xlabel('iterations')
plt.ylabel('tank level (m)')
#plt.xlim(left=0, right=288)
plt.legend()
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)

dd = plt.subplot(4,2,6)
minicps_ctown["T6_LEVEL"].plot(label='MiniCPS - PDD', ax=dd)
#minicps_ctown_synched["T6_LEVEL"].plot(label='Generic PLC1 Test', ax=dd)
minicps_ctown_general_plc["T6_LEVEL"].plot(label='Generic Test', ax=dd)
minicps_ctown_general_run["T6_LEVEL"].plot(label='Generic Run', ax=dd)
minicps_ctown_new_year["T6_LEVEL"].plot(label='New Year Run', ax=dd)
#minicps_ctown_plc1_attack_no_change["T6_LEVEL"].plot(label='Synch - PLC1 Attack', ax=dd)
#minicps_ctown_plc1_attack_off["T6_LEVEL"].plot(label='Synch - PLC1 Attack', ax=dd)
#minicps_ctown_mitm_plc5_attack["T6_LEVEL"].plot(label='MiniCPS - Mitm PLC5 Attack', ax=dd)
#minicps_ctown_plc7_plc5_exp_attack["T6_LEVEL"].plot(label='C-Town PLC7 Exponential Attack', ax=dd)
plt.title("CTown topology - Tank 6")
plt.xlabel('iterations')
plt.ylabel('tank level (m)')
plt.xlim(left=0, right=288)
plt.legend()
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)

dd = plt.subplot(4,2,7)
minicps_ctown["T7_LEVEL"].plot(label='MiniCPS - PDD', ax=dd)
#minicps_ctown_synched["T7_LEVEL"].plot(label='Generic PLC1 Test', ax=dd)
minicps_ctown_general_plc["T7_LEVEL"].plot(label='Generic Test', ax=dd)
minicps_ctown_general_run["T7_LEVEL"].plot(label='Generic Run', ax=dd)
minicps_ctown_new_year["T7_LEVEL"].plot(label='New Year Run', ax=dd)
#plt.xlim(left=0, right=288)
#minicps_ctown_plc1_attack_no_change["T7_LEVEL"].plot(label='Synch - PLC1 Attack - No change', ax=dd)
#minicps_ctown_plc1_attack_off["T7_LEVEL"].plot(label='Synch - PLC1 Attack', ax=dd)
#minicps_ctown_mitm_plc5_attack["T7_LEVEL"].plot(label='MiniCPS - Mitm PLC5 Attack', ax=dd)
#minicps_ctown_plc7_plc5_exp_attack["T7_LEVEL"].plot(label='C-Town PLC7 Exponential Attack', ax=dd)
plt.title("CTown topology topology - Tank 7")
plt.xlabel('iterations')
plt.ylabel('tank level (m)')
plt.xlim(left=0, right=288)
plt.legend()
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)
