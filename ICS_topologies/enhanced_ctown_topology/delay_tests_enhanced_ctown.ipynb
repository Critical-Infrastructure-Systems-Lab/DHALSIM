# %%
import matplotlib.pyplot as plt
import wntr
import wntr.network.controls as controls
import sqlite3
import csv
import time
import pandas as pd

# %%
# Results without delays
no_delay_ctown = pd.read_csv('no_attack/output_working_old/physical_process.csv')
small_delay_small_loss = pd.read_csv('desktop_test/output/physical_process.csv')
large_delay_small_loss = pd.read_csv('large_delay_small_loss/output/physical_process.csv')
small_delay_large_loss = pd.read_csv('small_delay_large_loss/output/physical_process.csv')
large_delay_large_loss = pd.read_csv('large_delay_large_loss/output/physical_process.csv')
subplot_hspace = 0.6
subplot_wspace = 0.1


dd = plt.subplot(4,2,1)
no_delay_ctown["T1_LEVEL"].plot(label='No delay - No loss', ax=dd)
small_delay_small_loss["T1_LEVEL"].plot(label='Small delay - Small loss', ax=dd)
#large_delay_small_loss["T1_LEVEL"].plot(label='Large delay - Small loss', ax=dd)
#small_delay_large_loss["T1_LEVEL"].plot(label='Small delay - Large loss', ax=dd)
large_delay_large_loss["T1_LEVEL"].plot(label='Large delay - Large loss', ax=dd)
plt.title("CTown topology - Tank 1")
plt.xlabel('iterations')
plt.ylabel('tank level (m)')
plt.legend()
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)

dd = plt.subplot(4,2,2)
no_delay_ctown["T2_LEVEL"].plot(label='No delay - No loss', ax=dd)
small_delay_small_loss["T2_LEVEL"].plot(label='Small delay - Small loss', ax=dd)
#large_delay_small_loss["T2_LEVEL"].plot(label='Large delay - Small loss', ax=dd)
#small_delay_large_loss["T2_LEVEL"].plot(label='Small delay - Large loss', ax=dd)
large_delay_large_loss["T2_LEVEL"].plot(label='Large delay - Large loss', ax=dd)
plt.title("CTown topology - Tank 2")
plt.xlabel('iterations')
plt.ylabel('tank level (m)')
plt.legend()
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)

dd = plt.subplot(4,2,3)
no_delay_ctown["T3_LEVEL"].plot(label='No delay - No loss', ax=dd)
small_delay_small_loss["T3_LEVEL"].plot(label='Small delay - Small loss', ax=dd)
#large_delay_small_loss["T3_LEVEL"].plot(label='Large delay - Small loss', ax=dd)
#small_delay_large_loss["T3_LEVEL"].plot(label='Small delay - Large loss', ax=dd)
large_delay_large_loss["T3_LEVEL"].plot(label='Large delay - Large loss', ax=dd)
plt.title("CTown topology - Tank 3")
plt.xlabel('iterations')
plt.ylabel('tank level (m)')
plt.legend()
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)

dd = plt.subplot(4,2,4)
no_delay_ctown["T4_LEVEL"].plot(label='No delay - No loss', ax=dd)
small_delay_small_loss["T4_LEVEL"].plot(label='Small delay - Small loss', ax=dd)
#large_delay_small_loss["T4_LEVEL"].plot(label='Large delay - Small loss', ax=dd)
#small_delay_large_loss["T4_LEVEL"].plot(label='Small delay - Large loss', ax=dd)
large_delay_large_loss["T4_LEVEL"].plot(label='Large delay - Large loss', ax=dd)
plt.title("CTown topology - Tank 4")
plt.xlabel('iterations')
plt.ylabel('tank level (m)')
plt.legend()
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)

dd = plt.subplot(4,2,5)
no_delay_ctown["T5_LEVEL"].plot(label='No delay - No loss', ax=dd)
small_delay_small_loss["T5_LEVEL"].plot(label='Small delay - Small loss', ax=dd)
#large_delay_small_loss["T5_LEVEL"].plot(label='Large delay - Small loss', ax=dd)
#small_delay_large_loss["T5_LEVEL"].plot(label='Small delay - Large loss', ax=dd)
large_delay_large_loss["T5_LEVEL"].plot(label='Large delay - Large loss', ax=dd)
plt.title("CTown topology - Tank 5")
plt.xlabel('iterations')
plt.ylabel('tank level (m)')
plt.legend()
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)

dd = plt.subplot(4,2,6)
no_delay_ctown["T6_LEVEL"].plot(label='No delay - No loss', ax=dd)
small_delay_small_loss["T6_LEVEL"].plot(label='Small delay - Small loss', ax=dd)
#large_delay_small_loss["T6_LEVEL"].plot(label='Large delay - Small loss', ax=dd)
#small_delay_large_loss["T6_LEVEL"].plot(label='Small delay - Large loss', ax=dd)
large_delay_large_loss["T6_LEVEL"].plot(label='Large delay - Large loss', ax=dd)
plt.title("CTown topology - Tank 6")
plt.xlabel('iterations')
plt.ylabel('tank level (m)')
plt.legend()
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)

dd = plt.subplot(4,2,7)
no_delay_ctown["T7_LEVEL"].plot(label='No delay - No loss', ax=dd)
#small_delay_small_loss["T7_LEVEL"].plot(label='Small delay - Small loss', ax=dd)
#large_delay_small_loss["T7_LEVEL"].plot(label='Large delay - Small loss', ax=dd)
small_delay_large_loss["T7_LEVEL"].plot(label='Small delay - Large loss', ax=dd)
large_delay_large_loss["T7_LEVEL"].plot(label='Large delay - Large loss', ax=dd)
plt.title("CTown topology topology - Tank 7")
plt.xlabel('iterations')
plt.ylabel('tank level (m)')
plt.legend()
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)
