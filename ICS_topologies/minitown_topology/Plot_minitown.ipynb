# %%
import matplotlib.pyplot as plt
import wntr
import wntr.network.controls as controls
import sqlite3
import csv
import time
import pandas as pd

# %%
minicps_minitown = pd.read_csv('week_0/physical_process.csv')
subplot_hspace = 0.6
subplot_wspace = 0.1
dd = plt.subplot(1,2,1)
minicps_minitown["TANK_LEVEL"].plot(label='Tank 1', ax=dd)
plt.title("Minitown Topology - Tank 1")
plt.xlabel('iterations')
plt.ylabel('tank level (m)')
plt.legend()
plt.subplots_adjust(top=2.00, right=3.00, hspace = subplot_hspace, wspace=subplot_wspace)
plt.grid(True)
